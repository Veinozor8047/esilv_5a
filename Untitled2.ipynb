# %%
import pandas as pd

# %%
df = pd.read_csv("./meteo.csv")

# %%
# %matplotlib notebook

# %%
df.groupby(["day", "hour"])["temperature"].mean().plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
